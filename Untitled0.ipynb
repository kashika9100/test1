# %% [markdown]
# <a href="https://colab.research.google.com/github/kashika9100/test1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#updatedcode1
#updated code
import pandas as pd

df=pd.read_excel("/content/drive/MyDrive/data operations/Session1_Exercise (2).xlsx")
print(df)
# as its extension is .xlsx so we use 'read_excel' like 'read_csv'
#use 'names' for chanding col index
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#EXAMPLECODE
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       1000 non-null   object
#  1   B       1000 non-null   object
#  2   C       1000 non-null   object
#  3   D       1000 non-null   object
#  4   E       1000 non-null   object
#  5   F       1000 non-null   int64
#  6   G       1000 non-null   int64
#  7   H       1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# df.isnull().sum()  or         df.isna().sum()
#
#
#  gives  you   the   sum   of   the  null   values   present   in  each  col   like   names  col   has  19   null  values  ,  etc.

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  997.000000     997.000000     997.000000
# mean    66.056169      69.119358      68.003009
# std     15.165514      14.583949      15.183582
# min      0.000000      17.000000      10.000000
# 25%     57.000000      59.000000      57.000000
# 50%     66.000000      70.000000      69.000000
# 75%     77.000000      79.000000      79.000000
# max    100.000000     100.000000     100.000000

# %%
df["Total"] = df[["math score","reading score","writing score"]].sum(axis=1)
df["Maximum"] = df[["math score","reading score","writing score"]].max(axis=1)
df["Minimum"] = df[["math score","reading score","writing score"]].min(axis=1)
df["Average"] = df[["math score","reading score","writing score"]].mean(axis=1)
print(df)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  total  \
# ...

# %%
df_sorted = df.sort_values(by="Average",ascending=False)
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  total  \
# ...

# %%
import pandas as pd
df=pd.DataFrame({"names":["a","b","c","d","e","f","g"],"age":[1,2,1,3,4,5,6],"marks":[12,13,14,15,16,17,18]})
df.insert(1,"wear",[1,2,3,4,5,6,7])

print(df)
# Out:
#   names  wear  age  marks
# 0     a     1    1     12
# 1     b     2    2     13
# 2     c     3    1     14
# 3     d     4    3     15
# 4     e     5    4     16
# 5     f     6    5     17
# 6     g     7    6     18
